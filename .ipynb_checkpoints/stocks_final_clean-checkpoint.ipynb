# %%
# import stock_info module from yahoo_fin
#reference 
# !pip install requests-html
import requests
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import pandas as pd
from yahoo_fin import stock_info as si
from yahoo_fin.stock_info import get_data, tickers_sp500, tickers_nasdaq, tickers_other, get_quote_table
import matplotlib.pyplot as plt
import numpy as np

def sp_100_with_company_name(listonly=False):
    sp100 = pd.read_html("https://en.wikipedia.org/wiki/S%26P_100")[2]
    sp100["Symbol"] = sp100["Symbol"].str.replace(".", "-")
    if listonly:
        sp100_tickers = sp100.Symbol.tolist()
        sp100_tickers = sorted(sp100_tickers)     
        return sp100_tickers
    return sp100

def sp_500():
    sp500 = pd.read_html("https://en.wikipedia.org/wiki/List_of_S%26P_500_companies")[0]
    sp500["Symbol"] = sp500["Symbol"].str.replace(".", "-")
    sp_tickers = sp500.Symbol.tolist()
    sp_tickers = sorted(sp_tickers)
    return sp_tickers

sp100 = sp_100_with_company_name()

def company_info(x):
    selected_company = sp100[sp100['Symbol'] == x]
    return x, selected_company['Name'].values[0], selected_company['Sector'].values[0]

def track_plot():
    tracking = []
    trackingB = []
    for x in sp100.Symbol.tolist():
        vars()[x] = get_data(x)
        # vars()[x] = vars()[x][(vars()[x].index>'2017-01-01')]
        # plt.plot(vars()[x].index, vars()[x]['close'], 'r')
        # plt.title(print(company_info(x),'Stock Price'))
        # plt.ylabel('Price ($)')
        # plt.show()
        vars()[x] = vars()[x][(vars()[x].index>'2023-01-01')]
        increase_table = vars()[x]['close'].rolling(3).apply(lambda x: np.all(np.diff(x) < 0)).astype('boolean')
        increase_table.sum()
        tracking.append({'stock': {company_info(x)}, 'score' : increase_table.sum()})    
        trackingB.append({'stock': x, 'score' : increase_table.sum()})
    return trackingB
           
# have market cap as in the index so that we can see how large is the company as well
# is this the list?? # Get the list of S&P 100 symbols
#sp100_symbols = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'FB', 'JPM', 'V', 'PG', 'INTC', 'CSCO', 'C', 'VZ', 'T', 'IBM', 'XOM', 'BA', 'DIS', 'HD', 'GS', 'WMT', 'MCD', 'NKE', 'KO', 'PEP', 'JNJ', 'CVX', 'MRK', 'PFE', 'SPG', 'ABBV', 'TXN', 'TSLA', 'NFLX', 'COST', 'UNH', 'PYPL', 'GOOG', 'ORCL', 'AVGO', 'ACN', 'AMGN', 'INTU', 'GS', 'MS', 'GE', 'LMT', 'MMM', 'MSI', 'SO', 'ABT', 'MDT', 'DHR', 'LIN', 'UPS', 'LOW', 'BLK', 'AXP', 'CAT', 'RTX', 'USB', 'CVS', 'TMO', 'ADBE', 'CME', 'ADP', 'PM', 'ISRG', 'FIS', 'FDX', 'TMUS', 'LRCX', 'AMD', 'BDX', 'APD', 'ANTM', 'NOW', 'SCHW', 'ZTS', 'AMD', 'EQIX', 'BIIB', 'FDX', 'MU', 'ICE', 'NSC', 'ITW', 'CHTR', 'CCI', 'ECL', 'EADSY', 'GD', 'KMB', 'EMR', 'ALL', 'PLD']

# pd.DataFrame(tracking).sort_values(by=['score'], ascending=False).head(40)
# # plot the above to se how those graph looks like
# pd.DataFrame(tracking).sort_values(by=['score'], ascending=False).head(30)    

# the biggest drops and dips are seen here 
def sort_and_plot(cut_date='2015-01-01'):
    trackingB = track_plot()
    sorted_list = sorted(trackingB, key=lambda x: x['score'], reverse=True)
    sorted_names = [item['stock'] for item in sorted_list]#[0:20]
    for x in sorted_names:
        vars()[x] = get_data(x)
        vars()[x] = vars()[x][(vars()[x].index>'2015-01-01')]
        plt.plot(vars()[x].index, vars()[x]['close'], 'r')
        plt.title(print(company_info(x),'Stock Price'))
        plt.ylabel('Price ($)')
        plt.show()

# %%
sort_and_plot()

# %%
sort_and_plot(cut_date = '2015-01-01')
# Out:
# ('PFE', 'Pfizer', 'Health Care') Stock Price
# ('JNJ', 'Johnson & Johnson', 'Health Care') Stock Price
# ('MMM', '3M', 'Industrials') Stock Price
# ('BMY', 'Bristol Myers Squibb', 'Health Care') Stock Price
# ('AMT', 'American Tower', 'Real Estate') Stock Price
# ('BAC', 'Bank of America', 'Financials') Stock Price
# ('PM', 'Philip Morris International', 'Consumer Staples') Stock Price
# ('UPS', 'United Parcel Service', 'Industrials') Stock Price
# ('MS', 'Morgan Stanley', 'Financials') Stock Price
# ('SO', 'Southern Company', 'Utilities') Stock Price
# ('RTX', 'RTX Corporation', 'Industrials') Stock Price
# ('AMGN', 'Amgen', 'Health Care') Stock Price
# ('COF', 'Capital One', 'Financials') Stock Price
# ('NKE', 'Nike', 'Consumer Discretionary') Stock Price
# ('XOM', 'ExxonMobil', 'Energy') Stock Price
# ('CVS', 'CVS Health', 'Health Care') Stock Price
# ('MDT', 'Medtronic', 'Health Care') Stock Price
# ('TGT', 'Target', 'Consumer Discretionary') Stock Price
# ('DUK', 'Duke Energy', 'Utilities') Stock Price
# ('USB', 'U.S. Bank', 'Financials') Stock Price
# ('EMR', 'Emerson', 'Industrials') Stock Price
# ('MO', 'Altria', 'Consumer Staples') Stock Price
# ('SBUX', 'Starbucks', 'Consumer Discretionary') Stock Price
# ('BLK', 'BlackRock', 'Financials') Stock Price
# ('FDX', 'FedEx', 'Industrials') Stock Price
# ('NEE', 'NextEra Energy', 'Utilities') Stock Price
# ('SCHW', 'Charles Schwab', 'Financials') Stock Price
# ('CVX', 'Chevron', 'Energy') Stock Price
# ('EXC', 'Exelon', 'Utilities') Stock Price
# ('GILD', 'Gilead', 'Health Care') Stock Price
# ('MCD', "McDonald's", 'Consumer Discretionary') Stock Price
# ('UNH', 'UnitedHealth Group', 'Health Care') Stock Price
# ('AXP', 'American Express', 'Financials') Stock Price
# ('CAT', 'Caterpillar', 'Industrials') Stock Price
# ('COP', 'ConocoPhillips', 'Energy') Stock Price
# ('PEP', 'PepsiCo', 'Consumer Staples') Stock Price
# ('PG', 'Procter & Gamble', 'Consumer Staples') Stock Price
# ('ABBV', 'AbbVie', 'Health Care') Stock Price
# ('ABT', 'Abbott', 'Health Care') Stock Price
# ('BA', 'Boeing', 'Industrials') Stock Price
# ('C', 'Citigroup', 'Financials') Stock Price
# ('DE', 'Deere & Company', 'Industrials') Stock Price
# ('DOW', 'Dow', 'Materials') Stock Price
# ('GD', 'General Dynamics', 'Industrials') Stock Price
# ('HON', 'Honeywell', 'Industrials') Stock Price
# ('LOW', "Lowe's", 'Consumer Discretionary') Stock Price
# ('F', 'Ford', 'Consumer Discretionary') Stock Price
# ('GS', 'Goldman Sachs', 'Financials') Stock Price
# ('LMT', 'Lockheed Martin', 'Industrials') Stock Price
# ('T', 'AT&T', 'Communication Services') Stock Price
# ('TMO', 'Thermo Fisher Scientific', 'Health Care') Stock Price
# ('TMUS', 'T-Mobile', 'Communication Services') Stock Price
# ('CHTR', 'Charter Communications', 'Communication Services') Stock Price
# ('DIS', 'Disney', 'Communication Services') Stock Price
# ('GM', 'GM', 'Consumer Discretionary') Stock Price
# ('NFLX', 'Netflix', 'Communication Services') Stock Price
# ('BK', 'BNY Mellon', 'Financials') Stock Price
# ('BRK-B', 'Berkshire Hathaway (Class B)', 'Financials') Stock Price
# ('INTC', 'Intel', 'Information Technology') Stock Price
# ('UNP', 'Union Pacific', 'Industrials') Stock Price
# ('ADBE', 'Adobe', 'Information Technology') Stock Price
# ('KHC', 'Kraft Heinz', 'Consumer Staples') Stock Price
# ('KO', 'Coca-Cola', 'Consumer Staples') Stock Price
# ('MET', 'MetLife', 'Financials') Stock Price
# ('CSCO', 'Cisco', 'Information Technology') Stock Price
# ('MRK', 'Merck', 'Health Care') Stock Price
# ('SPG', 'Simon', 'Real Estate') Stock Price
# ('AMD', 'AMD', 'Information Technology') Stock Price
# ('BKNG', 'Booking Holdings', 'Consumer Discretionary') Stock Price
# ('CL', 'Colgate-Palmolive', 'Consumer Staples') Stock Price
# ('CRM', 'Salesforce', 'Information Technology') Stock Price
# ('GOOG', 'Alphabet (Class C)', 'Communication Services') Stock Price
# ('IBM', 'IBM', 'Information Technology') Stock Price
# ('TSLA', 'Tesla', 'Consumer Discretionary') Stock Price
# ('TXN', 'Texas Instruments', 'Information Technology') Stock Price
# ('VZ', 'Verizon', 'Communication Services') Stock Price
# ('AVGO', 'Broadcom', 'Information Technology') Stock Price
# ('MDLZ', 'Mondelēz International', 'Consumer Staples') Stock Price
# ('NVDA', 'Nvidia', 'Information Technology') Stock Price
# ('WFC', 'Wells Fargo', 'Financials') Stock Price
# ('GOOGL', 'Alphabet (Class A)', 'Communication Services') Stock Price
# ('MSFT', 'Microsoft', 'Information Technology') Stock Price
# ('ACN', 'Accenture', 'Information Technology') Stock Price
# ('MA', 'Mastercard', 'Information Technology') Stock Price
# ('META', 'Meta', 'Communication Services') Stock Price
# ('QCOM', 'Qualcomm', 'Information Technology') Stock Price
# ('WMT', 'Walmart', 'Consumer Staples') Stock Price
# ('HD', 'Home Depot', 'Consumer Discretionary') Stock Price
# ('CMCSA', 'Comcast', 'Communication Services') Stock Price
# ('JPM', 'JPMorgan Chase', 'Financials') Stock Price
# ('LIN', 'Linde', 'Materials') Stock Price
# ('DHR', 'Danaher', 'Health Care') Stock Price
# ('ORCL', 'Oracle', 'Information Technology') Stock Price
# ('V', 'Visa', 'Information Technology') Stock Price
# ('GE', 'GE', 'Industrials') Stock Price
# ('LLY', 'Lilly', 'Health Care') Stock Price
# ('AAPL', 'Apple', 'Information Technology') Stock Price
# ('AIG', 'American International Group', 'Financials') Stock Price
# ('PYPL', 'PayPal', 'Information Technology') Stock Price
# ('AMZN', 'Amazon', 'Consumer Discretionary') Stock Price
# ('COST', 'Costco', 'Consumer Staples') Stock Price

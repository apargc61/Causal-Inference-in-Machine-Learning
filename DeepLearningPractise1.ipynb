# %%
# !pip install tensorflow==2.3.0
# !pip install gym
# !pip install keras
# !pip install keras-rl2
# Out:
# Requirement already satisfied: tensorflow==2.3.0 in c:\users\t430\anaconda3\lib\site-packages (2.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow==2.3.0) (1.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow==2.3.0) (1.15.0)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow==2.3.0) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow==2.3.0) (3.3.0)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow==2.3.0) (1.18.5)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow==2.3.0) (0.10.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow==2.3.0) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow==2.3.0) (1.11.2)
# Requirement already satisfied: scipy==1.4.1 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow==2.3.0) (1.4.1)
# Requirement already satisfied: wheel>=0.26 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow==2.3.0) (0.34.2)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow==2.3.0) (2.3.0)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow==2.3.0) (2.3.0)
# Requirement already satisfied: google-pasta>=0.1.8 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow==2.3.0) (0.2.0)
# Requirement already satisfied: gast==0.3.3 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow==2.3.0) (0.3.3)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow==2.3.0) (3.13.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow==2.3.0) (2.10.0)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow==2.3.0) (1.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\t430\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (49.2.0.post20200714)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\t430\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.7.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\t430\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.21.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\t430\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\t430\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.24.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\t430\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.2.2)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\t430\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in c:\users\t430\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\t430\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\t430\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\t430\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.3.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\t430\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\t430\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\t430\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\t430\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.0.4)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\t430\anaconda3\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3.5"->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\t430\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.1.0)
# Requirement already satisfied: gym in c:\users\t430\anaconda3\lib\site-packages (0.18.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in c:\users\t430\anaconda3\lib\site-packages (from gym) (1.5.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in c:\users\t430\anaconda3\lib\site-packages (from gym) (1.5.0)
# Requirement already satisfied: scipy in c:\users\t430\anaconda3\lib\site-packages (from gym) (1.4.1)
# Requirement already satisfied: Pillow<=7.2.0 in c:\users\t430\anaconda3\lib\site-packages (from gym) (7.2.0)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\t430\anaconda3\lib\site-packages (from gym) (1.18.5)
# Requirement already satisfied: future in c:\users\t430\anaconda3\lib\site-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.18.2)
# Requirement already satisfied: keras in c:\users\t430\anaconda3\lib\site-packages (2.4.3)
# Requirement already satisfied: h5py in c:\users\t430\anaconda3\lib\site-packages (from keras) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in c:\users\t430\anaconda3\lib\site-packages (from keras) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\t430\anaconda3\lib\site-packages (from keras) (1.18.5)
# Requirement already satisfied: pyyaml in c:\users\t430\anaconda3\lib\site-packages (from keras) (5.3.1)
# Requirement already satisfied: six in c:\users\t430\anaconda3\lib\site-packages (from h5py->keras) (1.15.0)
# Requirement already satisfied: keras-rl2 in c:\users\t430\anaconda3\lib\site-packages (1.0.4)
# Requirement already satisfied: tensorflow>=2.1.0 in c:\users\t430\anaconda3\lib\site-packages (from keras-rl2) (2.3.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (1.15.0)
# Requirement already satisfied: gast==0.3.3 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (0.3.3)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (1.18.5)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (2.10.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (3.13.0)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (1.6.3)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (0.10.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (1.1.0)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (2.3.0)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (1.11.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (3.3.0)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (1.31.0)
# Requirement already satisfied: google-pasta>=0.1.8 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (0.2.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (0.34.2)
# Requirement already satisfied: scipy==1.4.1 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (1.4.1)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (2.3.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in c:\users\t430\anaconda3\lib\site-packages (from tensorflow>=2.1.0->keras-rl2) (1.1.2)
# Requirement already satisfied: setuptools in c:\users\t430\anaconda3\lib\site-packages (from protobuf>=3.9.2->tensorflow>=2.1.0->keras-rl2) (49.2.0.post20200714)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\t430\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\t430\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (2.24.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\t430\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (0.4.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\t430\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (1.21.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\t430\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (1.7.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\t430\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (3.2.2)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\t430\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\t430\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\t430\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\t430\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (3.0.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\t430\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (1.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in c:\users\t430\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\t430\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (4.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\t430\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (0.2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\t430\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\t430\anaconda3\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3.5"->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (0.4.8)

# %%
import gym 
import random

# %%
env = gym.make('CartPole-v0')
states = env.observation_space.shape[0]
actions = env.action_space.n

# %%
episodes = 10
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = random.choice([0,1])
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# ...
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     657                 else:
#     658                     result = 0
# --> 659                     self._event_queue.append((event_handler, msg,
#     660                                               wParam, lParam))
#     661             if result is None:
#
# MemoryError:

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam

# %%
def build_model(states, actions):
    model = Sequential()
    model.add(Flatten(input_shape=(1,states)))
    model.add(Dense(24, activation='relu'))
    model.add(Dense(24, activation='relu'))
    model.add(Dense(actions, activation='linear'))
    return model

# %%
model = build_model(states, actions)

# %%
model.summary()

# %%
from rl.agents import DQNAgent
from rl.policy import BoltzmannQPolicy
from rl.memory import SequentialMemory

# %%
def build_agent(model, actions):
    policy = BoltzmannQPolicy()
    memory = SequentialMemory(limit=50000, window_length=1)
    dqn = DQNAgent(model=model, memory=memory, policy=policy, 
                  nb_actions=actions, nb_steps_warmup=10, target_model_update=1e-2)
    return dqn

# %%
dqn = build_agent(model, actions)
dqn.compile(Adam(lr=1e-3), metrics=['mae'])
dqn.fit(env, nb_steps=50000, visualize=False, verbose=1)

# %%
scores = dqn.test(env, nb_episodes=100, visualize=False)
print(np.mean(scores.history['episode_reward']))

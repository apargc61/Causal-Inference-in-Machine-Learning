# %%
import numpy as np
import pandas as pd

# %%
di = {
    'first' : np.random.randint(1, 10, 9),
    'second': np.random.randint(1,10,9),
    'last': np.random.uniform(0,10,9)
}

# %%
df = pd.DataFrame(di)
df.groupby('first')[['second', 'last']].sum().sort_values('last', ascending=True)
# Out:
#        second       last
# first
# 5           7   0.811448
# 6           5   1.094473
# 3           9   2.846801
# 4           6   3.618544
# 2           3   5.923684
# 1          22  24.605466

# %%
df.pivot(index='first', columns='second',values='last')
# Out:
# second         3         4         5         6         7         9
# first
# 4            NaN       NaN       NaN       NaN  9.947490       NaN
# 5            NaN  2.410751       NaN       NaN       NaN       NaN
# 6            NaN       NaN       NaN  9.991008  1.012775  5.135532
# 7            NaN       NaN       NaN  3.067356       NaN       NaN
# 8       7.630182       NaN       NaN       NaN       NaN  6.207326
# 9            NaN       NaN  0.934883       NaN       NaN       NaN

# %%
df['new'] = 0
df.loc[((df['first'] > 4) & (df['second'] > 7)), 'new'] = 1
df
# Out:
#    first  second      last  new
# 0      4       7  9.947490    0
# 1      6       9  5.135532    1
# 2      6       7  1.012775    0
# 3      9       5  0.934883    0
# 4      8       9  6.207326    1
# 5      8       3  7.630182    0
# 6      6       6  9.991008    0
# 7      5       4  2.410751    0
# 8      7       6  3.067356    0

# %%
df.drop(df[df['new']==1].index)  #needs double df inside
# Out:
#    first  second      last  new
# 0      4       7  9.947490    0
# 2      6       7  1.012775    0
# 3      9       5  0.934883    0
# 5      8       3  7.630182    0
# 6      6       6  9.991008    0
# 7      5       4  2.410751    0
# 8      7       6  3.067356    0

# %%
[df['new']==1]
# Out:
# [0    False
#  1     True
#  2    False
#  3    False
#  4     True
#  5    False
#  6    False
#  7    False
#  8    False
#  Name: new, dtype: bool]

# %%
df.drop('new',axis=1)
# Out:
#    first  second      last
# 0      4       7  9.947490
# 1      6       9  5.135532
# 2      6       7  1.012775
# 3      9       5  0.934883
# 4      8       9  6.207326
# 5      8       3  7.630182
# 6      6       6  9.991008
# 7      5       4  2.410751
# 8      7       6  3.067356

# %%
df
# Out:
#    first  second      last  new
# 0      4       7  9.947490    0
# 1      6       9  5.135532    1
# 2      6       7  1.012775    0
# 3      9       5  0.934883    0
# 4      8       9  6.207326    1
# 5      8       3  7.630182    0
# 6      6       6  9.991008    0
# 7      5       4  2.410751    0
# 8      7       6  3.067356    0

# %%
from sklearn.utils import resample
from sklearn.model_selection import train_test_split

resample(df, replace=True, n_samples=10, random_state=123)
trx, trny, tx,ty = train_test_split(df,df,test_size=.5,random_state=123)

# %%
from statsmodels.api import OLS
OLS(df['last'], df[['first','second']]).fit().summary()
# Out:
# C:\Users\T430\anaconda3\lib\site-packages\scipy\stats\stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=9
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   last   R-squared (uncentered):                   0.673
# Model:                            OLS   Adj. R-squared (uncentered):              0.580
# Method:                 Least Squares   F-statistic:                              7.217
# Date:                Sun, 27 Feb 2022   Prob (F-statistic):                      0.0199
# Time:                        17:36:25   Log-Likelihood:                         -24.064
# No. Observations:                   9   AIC:                                      52.13
# Df Residuals:                       7   BIC:                                      52.52
# Df Model:                           2
# ...

# %%
from statsmodels.tsa.models.arima import ARIMA
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-48b4a5664cbd> in <module>
# ----> 1 from statsmodels.tsa.models.arima import ARIMA
#
# ModuleNotFoundError: No module named 'statsmodels.tsa.models'

# %%
help(statsmodels)
# Out:
# Help on package statsmodels:
#
# NAME
#     statsmodels
#
# PACKAGE CONTENTS
#     _version
#     api
#     base (package)
#     compat (package)
#     conftest
#     datasets (package)
#     discrete (package)
#     distributions (package)
#     duration (package)
#     emplike (package)
#     formula (package)
#     gam (package)
#     genmod (package)
#     graphics (package)
#     imputation (package)
#     interface (package)
#     iolib (package)
#     miscmodels (package)
#     multivariate (package)
#     nonparametric (package)
#     regression (package)
#     resampling (package)
#     robust (package)
#     sandbox (package)
#     src (package)
#     stats (package)
#     tests (package)
#     tools (package)
#     tsa (package)
#
# SUBMODULES
#     __init__
#
# FUNCTIONS
#     test(extra_args=None, exit=False)
#         Run the test suite
#
#         Parameters
#         ----------
#         extra_args : list[str]
# ...

# %%
df.rename(columns={'new':'supernew', last})

# %%
df
# Out:
#    first  second      last  new
# 0      4       7  9.947490    0
# 1      6       9  5.135532    1
# 2      6       7  1.012775    0
# 3      9       5  0.934883    0
# 4      8       9  6.207326    1
# 5      8       3  7.630182    0
# 6      6       6  9.991008    0
# 7      5       4  2.410751    0
# 8      7       6  3.067356    0

# %%
one = {
    'a': (1,2,4),
    'b': (1,1,2),
    'e': (5,6,7)
}

two = {
    'e':(5,6,7),
    'f':(2,2,2),
    'g':(5,5,5)
}

on = pd.DataFrame(one)
to = pd.DataFrame(two)

# %%
on
# Out:
#    a  b  e
# 0  1  1  5
# 1  2  1  6
# 2  4  2  7

# %%
to
# Out:
#    e  f  g
# 0  5  2  5
# 1  6  2  5
# 2  7  2  5

# %%
pd.merge(on, to , on='e', how='inner')
# Out:
#    a  b  e  f  g
# 0  1  1  5  2  5
# 1  2  1  6  2  5
# 2  4  2  7  2  5

# %%
pd.merge(on, to, on='e', how='outer')
# Out:
#    a  b  e  f  g
# 0  1  1  5  2  5
# 1  2  1  6  2  5
# 2  4  2  7  2  5

# %%
pd.merge(on,to,how='outer')
# Out:
#    a  b  e  f  g
# 0  1  1  5  2  5
# 1  2  1  6  2  5
# 2  4  2  7  2  5

# %%
pd.concat([on,to],axis=0)
# Out:
#      a    b  e    f    g
# 0  1.0  1.0  5  NaN  NaN
# 1  2.0  1.0  6  NaN  NaN
# 2  4.0  2.0  7  NaN  NaN
# 0  NaN  NaN  5  2.0  5.0
# 1  NaN  NaN  6  2.0  5.0
# 2  NaN  NaN  7  2.0  5.0

# %%
df.loc[1:2,['first','second']] #label based
# Out:
#    first  second
# 1      6       9
# 2      6       7

# %%
df.iloc[1:2,0:2] #integer based
# Out:
#    first  second
# 1      6       9

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
ARIMA(df['first'], order=(1,1,1)).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  first   No. Observations:                    9
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                 -15.366
# Date:                Mon, 28 Feb 2022   AIC                             36.732
# Time:                        22:32:03   BIC                             36.970
# Sample:                             0   HQIC                            35.124
#                                   - 9
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6724      0.959     -0.701      0.483      -2.553       1.208
# ma.L1          0.4756      1.453      0.327      0.743      -2.372       3.323
# sigma2         2.6985      2.578      1.047      0.295      -2.353       7.750
# ...

# %%
df
# Out:
#    first  second      last  new
# 0      4       7  9.947490    0
# 1      6       9  5.135532    1
# 2      6       7  1.012775    0
# 3      9       5  0.934883    0
# 4      8       9  6.207326    1
# 5      8       3  7.630182    0
# 6      6       6  9.991008    0
# 7      5       4  2.410751    0
# 8      7       6  3.067356    0

# %%
df.drop(df[df['first']==7].index)
# Out:
#    first  second      last  new
# 0      4       7  9.947490    0
# 1      6       9  5.135532    1
# 2      6       7  1.012775    0
# 3      9       5  0.934883    0
# 4      8       9  6.207326    1
# 5      8       3  7.630182    0
# 6      6       6  9.991008    0
# 7      5       4  2.410751    0

# %%
df.drop(['new', 'last'],axis=1)
# Out:
#    first  second
# 0      4       7
# 1      6       9
# 2      6       7
# 3      9       5
# 4      8       9
# 5      8       3
# 6      6       6
# 7      5       4
# 8      7       6

# %%
df.loc[[5,8],['last','new']]
# Out:
#        last  new
# 5  7.630182    0
# 8  3.067356    0

# %%
df.iloc[[0,1,2], [2]]
# Out:
#        last
# 0  9.947490
# 1  5.135532
# 2  1.012775

# %%
df.loc[[0,1],]
# Out:
#    first  second      last  new
# 0      4       7  9.947490    0
# 1      6       9  5.135532    1

# %%
df.groupby('new')[['second', 'last']].sum().sort_values('new', ascending=False)
# Out:
#      second       last
# new
# 1        18  11.342858
# 0        38  34.994444

# %%
df.pivot(columns='new', values='last')
# Out:
# new         0         1
# 0    9.947490       NaN
# 1         NaN  5.135532
# 2    1.012775       NaN
# 3    0.934883       NaN
# 4         NaN  6.207326
# 5    7.630182       NaN
# 6    9.991008       NaN
# 7    2.410751       NaN
# 8    3.067356       NaN

# %%
df.sort_values(['first','new'], ascending=True)
# Out:
#    first  second      last  new
# 0      4       7  9.947490    0
# 7      5       4  2.410751    0
# 2      6       7  1.012775    0
# 6      6       6  9.991008    0
# 1      6       9  5.135532    1
# 8      7       6  3.067356    0
# 5      8       3  7.630182    0
# 4      8       9  6.207326    1
# 3      9       5  0.934883    0

# %%
import numpy as np
np.array([[1,2,3],
         [4,5,6]])
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
#help(np.ones)

# %%
df.sort_values('first',ascending=True)
# Out:
#    first  second      last  new
# 0      4       7  9.947490    0
# 7      5       4  2.410751    0
# 1      6       9  5.135532    1
# 2      6       7  1.012775    0
# 6      6       6  9.991008    0
# 8      7       6  3.067356    0
# 4      8       9  6.207326    1
# 5      8       3  7.630182    0
# 3      9       5  0.934883    0

# %%
df.groupby('new')[['last','second']].sum()
# Out:
#           last  second
# new
# 0    34.994444      38
# 1    11.342858      18

# %%
pd.merge(on,to,on='e',how='inner')
# Out:
#    a  b  e  f  g
# 0  1  1  5  2  5
# 1  2  1  6  2  5
# 2  4  2  7  2  5

# %%
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from statsmodels.api import OLS
from statsmodels.tsa.arima.model import ARIMA

# %%
resample(df, )
pd.merge(first,second, on='key', how='inner')
pd.concat([first,second], axis=1)
df.rename(columns={'fiest': 'one', 'second':'two'}, inplace=True)

# %%
df.groupby('first')[['second']].sum().sort_values('second', ascending=True)
# Out:
#        second
# first
# 2           3
# 6           5
# 4           6
# 5           7
# 3           9
# 1          22

# %%
df.rename(columns={'first': 'one', 'second':'two'}, inplace=True)

# %%
df
# Out:
#    one  two      last
# 0    3    9  2.846801
# 1    6    5  1.094473
# 2    2    3  5.923684
# 3    1    3  4.359313
# 4    1    3  6.190453
# 5    4    6  3.618544
# 6    1    7  8.472320
# 7    1    9  5.583380
# 8    5    7  0.811448

# %%
resample(df, n_samples=5, replace=False, random_state=123)
# Out:
#    one  two      last
# 7    1    9  5.583380
# 0    3    9  2.846801
# 5    4    6  3.618544
# 6    1    7  8.472320
# 3    1    3  4.359313

# %%
OLS(df['two'], df[['one','last']]).fit().summary()
# Out:
# C:\Users\T430\anaconda3\lib\site-packages\scipy\stats\stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=9
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                    two   R-squared (uncentered):                   0.843
# Model:                            OLS   Adj. R-squared (uncentered):              0.799
# Method:                 Least Squares   F-statistic:                              18.86
# Date:                Sun, 06 Mar 2022   Prob (F-statistic):                     0.00152
# Time:                        17:29:56   Log-Likelihood:                         -20.872
# No. Observations:                   9   AIC:                                      45.74
# Df Residuals:                       7   BIC:                                      46.14
# Df Model:                           2
# ...

# %%
ARIMA(df['two'], order=(1,1,1)).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                    two   No. Observations:                    9
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                 -17.186
# Date:                Sun, 06 Mar 2022   AIC                             40.373
# Time:                        17:53:53   BIC                             40.611
# Sample:                             0   HQIC                            38.765
#                                   - 9
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4211      1.884      0.223      0.823      -3.272       4.114
# ma.L1         -0.0339      2.489     -0.014      0.989      -4.911       4.844
# sigma2         4.2112      2.645      1.592      0.111      -0.973       9.395
# ...
